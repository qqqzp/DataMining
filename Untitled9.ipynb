# %%
import pandas as pd
import numpy as np
import csv

#从csv中读数据
names = ['No','year','month','day','hour','pm2.5','DEWP','TEMP','PRES','cbwd','Iws','Is','Ir']# 列的名称
data = pd.read_csv("data1.csv",names=names,header=0,skiprows=24)
del (data['No'])
data.replace({'cv':0,'NW':1,'NE':2,'SE':3,'SW':4},inplace=True) 
data
# Out:
#        year  month  day  hour  pm2.5  DEWP  TEMP    PRES  cbwd     Iws  Is  Ir
# 0      2010      1    2     0  129.0   -16  -4.0  1020.0     3    1.79   0   0
# 1      2010      1    2     1  148.0   -15  -4.0  1020.0     3    2.68   0   0
# 2      2010      1    2     2  159.0   -11  -5.0  1021.0     3    3.57   0   0
# 3      2010      1    2     3  181.0    -7  -5.0  1022.0     3    5.36   1   0
# 4      2010      1    2     4  138.0    -7  -5.0  1022.0     3    6.25   2   0
# 5      2010      1    2     5  109.0    -7  -6.0  1022.0     3    7.14   3   0
# 6      2010      1    2     6  105.0    -7  -6.0  1023.0     3    8.93   4   0
# 7      2010      1    2     7  124.0    -7  -5.0  1024.0     3   10.72   0   0
# 8      2010      1    2     8  120.0    -8  -6.0  1024.0     3   12.51   0   0
# 9      2010      1    2     9  132.0    -7  -5.0  1025.0     3   14.30   0   0
# 10     2010      1    2    10  140.0    -7  -5.0  1026.0     3   17.43   1   0
# ...

# %%
from sklearn.model_selection import train_test_split
Y = dfn['pm2.5']
X = pd.DataFrame(dfn,columns=['year','month','day','hour','DEWP','TEMP','PRES','cbwd','Iws','Is','Ir'])
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42)

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)

# %%
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.3220920970322645
# RMSE: 0.5675315824095294

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)

# %%
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.76451775159547
# RMSE: 0.8743670577025818

# %%
from sklearn import svm
model = svm.SVR()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.48149211489560856
# RMSE: 0.6938963286367846

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.76451775159547
# RMSE: 0.8743670577025818

# %%
from sklearn import neighbors
model = neighbors.KNeighborsRegressor()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.35072139968320126
# RMSE: 0.592217358478457

# %%
from sklearn import ensemble
model = ensemble.GradientBoostingRegressor(n_estimators=100)#这里使用100个决策树
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
# Out:
# MSE: 0.5121278086734772
# RMSE: 0.7156310562527853

# %%
from sklearn.ensemble import BaggingRegressor
model = BaggingRegressor()
model.fit(x_train,y_train)
score = model.score(x_test, y_test)
result = model.predict(x_test)
from sklearn import metrics
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test))
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)))
f = open("result.txt", "w")
print("Bagging回归",file = f)
# 用scikit-learn计算MSE
print("MSE:",metrics.mean_squared_error(result, y_test),file = f)
# 用scikit-learn计算RMSE
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,result)),file = f)
f.close()
# Out:
# MSE: 0.20864530065906498
# RMSE: 0.45677707983114146
